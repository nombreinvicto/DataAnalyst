# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.axes._axes as axes
sns.set(style="whitegrid")

# %%
df = pd.read_csv('appointment.csv')
df.head(1)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
#
#          AppointmentDay  Age    Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62  JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.drop('PatientId', axis=1, inplace=True)
df.drop('AppointmentID', axis=1, inplace=True)

# %%
df[df.duplicated()].head()
# Out:
#     Gender          ScheduledDay        AppointmentDay  Age   Neighbourhood  \
# 154      F  2016-04-28T16:38:34Z  2016-04-29T00:00:00Z   30         ITARARÉ
# 369      F  2016-04-29T09:43:15Z  2016-04-29T00:00:00Z   39  PRAIA DO CANTO
# 371      F  2016-04-19T11:16:27Z  2016-04-29T00:00:00Z   11      BELA VISTA
# 466      F  2016-04-27T13:16:02Z  2016-04-29T00:00:00Z   49      CONSOLAÇÃO
# 554      M  2016-03-29T12:40:26Z  2016-04-29T00:00:00Z   40          CENTRO
#
#      Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  \
# 154            0             0         0           0        0             0
# 369            0             0         0           0        0             0
# 371            0             0         0           0        0             0
# 466            0             0         0           0        0             0
# 554            0             0         0           0        0             0
#
#     No-show
# 154      No
# 369      No
# ...

# %%
df[df.duplicated(keep='last')].head()
# Out:
#     Gender          ScheduledDay        AppointmentDay  Age   Neighbourhood  \
# 153      F  2016-04-28T16:38:34Z  2016-04-29T00:00:00Z   30         ITARARÉ
# 368      F  2016-04-29T09:43:15Z  2016-04-29T00:00:00Z   39  PRAIA DO CANTO
# 370      F  2016-04-19T11:16:27Z  2016-04-29T00:00:00Z   11      BELA VISTA
# 465      F  2016-04-27T13:16:02Z  2016-04-29T00:00:00Z   49      CONSOLAÇÃO
# 553      M  2016-03-29T12:40:26Z  2016-04-29T00:00:00Z   40          CENTRO
#
#      Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  \
# 153            0             0         0           0        0             0
# 368            0             0         0           0        0             0
# 370            0             0         0           0        0             0
# 465            0             0         0           0        0             0
# 553            0             0         0           0        0             0
#
#     No-show
# 153      No
# 368      No
# ...

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109892 entries, 0 to 110526
# Data columns (total 12 columns):
# Gender            109892 non-null object
# ScheduledDay      109892 non-null object
# AppointmentDay    109892 non-null object
# Age               109892 non-null int64
# Neighbourhood     109892 non-null object
# Scholarship       109892 non-null int64
# Hipertension      109892 non-null int64
# Diabetes          109892 non-null int64
# Alcoholism        109892 non-null int64
# Handcap           109892 non-null int64
# SMS_received      109892 non-null int64
# No-show           109892 non-null object
# dtypes: int64(7), object(5)
# memory usage: 10.9+ MB

# %%
df.shape
df.tail()
df.reset_index(inplace=True)
df.tail()
# Out:
#          index Gender          ScheduledDay        AppointmentDay  Age  \
# 109887  110522      F  2016-05-03T09:15:35Z  2016-06-07T00:00:00Z   56
# 109888  110523      F  2016-05-03T07:27:33Z  2016-06-07T00:00:00Z   51
# 109889  110524      F  2016-04-27T16:03:52Z  2016-06-07T00:00:00Z   21
# 109890  110525      F  2016-04-27T15:09:23Z  2016-06-07T00:00:00Z   38
# 109891  110526      F  2016-04-27T13:30:56Z  2016-06-07T00:00:00Z   54
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 109887   MARIA ORTIZ            0             0         0           0
# 109888   MARIA ORTIZ            0             0         0           0
# 109889   MARIA ORTIZ            0             0         0           0
# 109890   MARIA ORTIZ            0             0         0           0
# 109891   MARIA ORTIZ            0             0         0           0
#
#         Handcap  SMS_received No-show
# 109887        0             1      No
# 109888        0             1      No
# ...

# %%
df.rename(lambda name: name.lower(), axis=1, inplace=True)
df.head(1)
# Out:
#       patientid  appointmentid gender          scheduledday  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
#
#          appointmentday  age    neighbourhood  scholarship  hipertension  \
# 0  2016-04-29T00:00:00Z   62  JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received no-show
# 0         0           0        0             0      No

# %%
df['no-show'] = df['no-show'].map({'No': 0, 'Yes': 1})
df.head(1)
# Out:
#       patientid  appointmentid gender          scheduledday  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
#
#          appointmentday  age    neighbourhood  scholarship  hipertension  \
# 0  2016-04-29T00:00:00Z   62  JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received  no-show
# 0         0           0        0             0        0

# %%
df.drop(['patientid', 'appointmentid'], axis=1, inplace=True)

# %%
df.head(1)
# Out:
#   gender          scheduledday        appointmentday  age    neighbourhood  \
# 0      F  2016-04-29T18:38:08Z  2016-04-29T00:00:00Z   62  JARDIM DA PENHA
#
#    scholarship  hipertension  diabetes  alcoholism  handcap  sms_received  \
# 0            0             1         0           0        0             0
#
#    no-show
# 0        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110527 entries, 0 to 110526
# Data columns (total 12 columns):
# gender            110527 non-null object
# scheduledday      110527 non-null object
# appointmentday    110527 non-null object
# age               110527 non-null int64
# neighbourhood     110527 non-null object
# scholarship       110527 non-null int64
# hipertension      110527 non-null int64
# diabetes          110527 non-null int64
# alcoholism        110527 non-null int64
# handcap           110527 non-null int64
# sms_received      110527 non-null int64
# no-show           110527 non-null int64
# dtypes: int64(8), object(4)
# memory usage: 11.0+ MB

# %%
df.appointmentday = pd.to_datetime(df.appointmentday)

# %%
df.scheduledday = pd.to_datetime(df.scheduledday)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110527 entries, 0 to 110526
# Data columns (total 12 columns):
# gender            110527 non-null object
# scheduledday      110527 non-null datetime64[ns, UTC]
# appointmentday    110527 non-null datetime64[ns, UTC]
# age               110527 non-null int64
# neighbourhood     110527 non-null object
# scholarship       110527 non-null int64
# hipertension      110527 non-null int64
# diabetes          110527 non-null int64
# alcoholism        110527 non-null int64
# handcap           110527 non-null int64
# sms_received      110527 non-null int64
# no-show           110527 non-null int64
# dtypes: datetime64[ns, UTC](2), int64(8), object(2)
# memory usage: 11.0+ MB

# %%
df.columns.get_loc('scheduledday')
# Out:
# 1

# %%
colname = ['scheduledday', 'appointmentday']
for col in colname:
    year_colname = col[0:6] + '_year'
    month_colname = col[0:6] + '_month'
    day_colname = col[0:6] + '_day'
    hr_colname = col[0:6] + '_hr'
    names = [year_colname, month_colname, day_colname, hr_colname]
    
    year_series = df[col].dt.year
    month_series = df[col].dt.month_name()
    day_series = df[col].dt.weekday_name
    hr_series = df[col].dt.hour
    values = [year_series, month_series, day_series, hr_series]
    
    
    position = df.columns.get_loc(col) + 1
    for name, value in zip(names, values):
        df.insert(loc=position, column=name, value=value)
        position += 1

# %%
df.drop(labels=colname, axis=1, inplace=True)

# %%
df.appoin_hr.value_counts()
# Out:
# 0    110527
# Name: appoin_hr, dtype: int64

# %%
df.drop(labels='appoin_hr', axis=1, inplace=True)

# %%
df.groupby('schedu_day').sum()
# Out:
#             schedu_year  schedu_hr  appoin_year     age  scholarship  \
# schedu_day
# Friday         38132640     197878     38132640  715549         1752
# Monday         46539344     253584     46539360  852215         2276
# Saturday          48384        252        48384     927            3
# Thursday       36435167     197200     36435168  676654         1772
# Tuesday        52754643     282100     52754688  972843         2566
# Wednesday      48912192     259861     48912192  881134         2492
#
#             hipertension  diabetes  alcoholism  handcap  sms_received  no-show
# schedu_day
# Friday              3710      1344         648      426          7322     3887
# Monday              4488      1627         701      493          6309     4561
# Saturday               5         3           0        0             4        1
# Thursday            3720      1363         528      415          6256     3700
# ...

# %%
# almost no one schedules it on saturday
sns.countplot(data=df, x='schedu_day', order=df['schedu_day'].value_counts().index)

# %%
a = df.groupby('schedu_day',as_index=False).sum()
a
# Out:
#   schedu_day  schedu_year  schedu_hr  appoin_year     age  scholarship  \
# 0     Friday     38132640     197878     38132640  715549         1752
# 1     Monday     46539344     253584     46539360  852215         2276
# 2   Saturday        48384        252        48384     927            3
# 3   Thursday     36435167     197200     36435168  676654         1772
# 4    Tuesday     52754643     282100     52754688  972843         2566
# 5  Wednesday     48912192     259861     48912192  881134         2492
#
#    hipertension  diabetes  alcoholism  handcap  sms_received  no-show
# 0          3710      1344         648      426          7322     3887
# 1          4488      1627         701      493          6309     4561
# 2             5         3           0        0             4        1
# 3          3720      1363         528      415          6256     3700
# 4          5365      1997         746      630          7959     5291
# ...

# %%
# shows the amount of no-shows by day types - higher for higher schedule days
sns.barplot(data=a, x='schedu_day', y='no-show', order=df['schedu_day'].value_counts().index)

# %%
df.head(1)
# Out:
#   gender  schedu_year schedu_month schedu_day  schedu_hr  appoin_year  \
# 0      F         2016        April     Friday         18         2016
#
#   appoin_month appoin_day  age    neighbourhood  scholarship  hipertension  \
# 0        April     Friday   62  JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received  no-show
# 0         0           0        0             0        0

# %%
# female no shows are more than double of male no shows
c = df.groupby('gender', as_index=False).sum()
sns.barplot(data=c, x='gender', y='no-show')

# %%
df['schedu_year'].value_counts()
# Out:
# 2016    110465
# 2015        62
# Name: schedu_year, dtype: int64

# %%
# most appointments scheduled on 2016 so its only natural to find most of the no shows in 2016
d = df.groupby('schedu_year', as_index=False).sum()
sns.barplot(data=d, x='schedu_year', y='no-show')

# %%
df.head(1)
# Out:
#   gender  schedu_year schedu_month schedu_day  schedu_hr  appoin_year  \
# 0      F         2016        April     Friday         18         2016
#
#   appoin_month appoin_day  age    neighbourhood  scholarship  hipertension  \
# 0        April     Friday   62  JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received  no-show
# 0         0           0        0             0        0

# %%
df['schedu_month'].value_counts()
# Out:
# May         67421
# April       25339
# June        13750
# March        3614
# February      281
# December       61
# January        60
# November        1
# Name: schedu_month, dtype: int64

# %%
e = df.groupby('schedu_month', as_index=False).sum()
sns.barplot(data=e, x='schedu_month', y='no-show')
e
# Out:
#   schedu_month  schedu_year  schedu_hr  appoin_year      age  scholarship  \
# 0        April     51083424     279756     51083424   914662         2509
# 1     December       122915        732       122976     3868            5
# 2     February       566496       3301       566496    14371           11
# 3      January       120960        652       120960     3336            4
# 4         June     27720000     142422     27720000   509737         1420
# 5        March      7285824      41096      7285824   146784          207
# 6          May    135920736     722909    135920736  2506513         6705
# 7     November         2015          7         2016       51            0
#
#    hipertension  diabetes  alcoholism  handcap  sms_received  no-show
# 0          4562      1503         604      445         14444     7849
# 1            49         9           0        4            42       19
# 2            87        33           4       15           166       82
# ...

# %%
df['schedu_hr'].value_counts()
# Out:
# 7     19213
# 8     15349
# 9     12823
# 10    11056
# 14     9127
# 13     9036
# 11     8462
# 15     8079
# 16     5542
# 12     5422
# 17     2909
# 6      1578
# 18     1340
# 19      488
# 20      100
# 21        3
# Name: schedu_hr, dtype: int64

# %%
f = df.groupby('schedu_hr', as_index=False).sum()
sns.barplot(data=f, x='schedu_hr', y='no-show')
f
# Out:
#     schedu_hr  schedu_year  appoin_year     age  scholarship  hipertension  \
# 0           6      3181248      3181248   72833          106           454
# 1           7     38733407     38733408  711444         2050          4218
# 2           8     30943577     30943584  550926         1726          2996
# 3           9     25851168     25851168  468244         1234          2547
# 4          10     22288879     22288896  403898         1084          2174
# 5          11     17059392     17059392  329951          775          1719
# 6          12     10930752     10930752  207940          492          1157
# 7          13     18216564     18216576  312607          970          1570
# 8          14     18400007     18400032  326203          927          1583
# 9          15     16287264     16287264  304720          721          1517
# 10         16     11172672     11172672  211824          445           986
# ...

# %%
#youngers do more no shows
f = df.groupby('age', as_index=False).sum()

sns.scatterplot(data=f, x='age', y='no-show')

# %%
df.head(1)
# Out:
#   gender  schedu_year schedu_month schedu_day  schedu_hr  appoin_year  \
# 0      F         2016        April     Friday         18         2016
#
#   appoin_month appoin_day  age    neighbourhood  scholarship  hipertension  \
# 0        April     Friday   62  JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received  no-show
# 0         0           0        0             0        0

# %%
f = df.groupby('neighbourhood', as_index=False).sum()
f.head()
# Out:
#          neighbourhood  schedu_year  schedu_hr  appoin_year    age  \
# 0            AEROPORTO        16128         89        16128    425
# 1           ANDORINHAS      4560192      24640      4560192  81672
# 2      ANTÔNIO HONÓRIO       546336       3103       546336   9985
# 3  ARIOVALDO FAVALESSA       568512       2694       568512   9263
# 4       BARRO VERMELHO       852768       4550       852768  19052
#
#    scholarship  hipertension  diabetes  alcoholism  handcap  sms_received  \
# 0            0             2         0           0        0             1
# 1          323           586       299          52       91           567
# 2           14             5         3           0        1            93
# 3           52            37        19          14       11            57
# 4            0            57        23           2        6           143
#
#    no-show
# 0        1
# 1      521
# 2       50
# 3       62
# 4       91

# %%
f.sort_values(axis=0, by='no-show', ascending=False, inplace=True)
f
# Out:
#                   neighbourhood  schedu_year  schedu_hr  appoin_year     age  \
# 38               JARDIM CAMBURI     15557472      91455     15557472  337476
# 43                  MARIA ORTIZ     11702880      66852     11702880  204776
# 36                      ITARARÉ      7084224      37595      7084224  125895
# 59                  RESISTÊNCIA      8932895      47040      8932896  145865
# 10                       CENTRO      6721344      35177      6721344  141955
# 40            JESUS DE NAZARETH      5751648      29998      5751648   85531
# 39              JARDIM DA PENHA      7816032      44050      7816032  174413
# 9                     CARATOÍRA      5171040      25655      5171040   94958
# 78                   TABUAZEIRO      6314109      33226      6314112  109512
# 8                        BONFIM      5590368      30057      5590368   97552
# 33             ILHA DO PRÍNCIPE      4568256      23256      4568256   80905
# ...

# %%
df.groupby('hipertension', as_index=False).sum()
# Out:
#    hipertension  schedu_year  schedu_hr  appoin_year      age  scholarship  \
# 0             0    178871603     960679    178871616  2777885         8977
# 1             1     43950767     230196     43950816  1321437         1884
#
#    diabetes  alcoholism  handcap  sms_received  no-show
# 0      1457        2033     1405         28612    18547
# 1      6486        1327     1054          6870     3772

# %%
df.groupby('alcoholism', as_index=False).sum()
# Out:
#    alcoholism  schedu_year  schedu_hr  appoin_year      age  scholarship  \
# 0           0    216048610    1154838    216048672  3932687        10333
# 1           1      6773760      36037      6773760   166635          528
#
#    hipertension  diabetes  handcap  sms_received  no-show
# 0         20474      7611     2370         34635    21642
# 1          1327       332       89           847      677

# %%
df.groupby('handcap', as_index=False).sum()
# Out:
#    handcap  schedu_year  schedu_hr  appoin_year      age  scholarship  \
# 0        0    218304518    1166643    218304576  3986058        10683
# 1        1      4116668      22055      4116672   103846          160
# 2        2       368928       1983       368928     8743           18
# 3        3        26208        149        26208      632            0
# 4        4         6048         45         6048       43            0
#
#    hipertension  diabetes  alcoholism  sms_received  no-show
# 0         20833      7544        3282         34946    21912
# 1           883       356          70           489      366
# 2            84        43           5            43       37
# 3             1         0           3             3        3
# 4             0         0           0             1        1
